# %% [markdown]
# <a href="https://colab.research.google.com/github/filipecarbonera/machine_learning_basics/blob/main/machine_learning_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Stop wasting times to learn Machine Learning! Read this instead!
# [Fast-Track Your Machine Learning Journey with Python’s Built-in Datasets](https://medium.com/datadriveninvestor/stop-wasting-times-to-learn-machine-learning-read-this-instead-5abfab230279)

# %%
# Importando as bibliotecas necessárias.
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %% [markdown]
# ### Iris Dataset

# %%
# Carregando o Iris Dataset
iris = datasets.load_iris()

# %%
# Apresentando o nome das colunas e das variáveis alvo.
print("Feature names:", iris.feature_names)
print("Target names:", iris.target_names)
# Out:
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names: ['setosa' 'versicolor' 'virginica']

# %%
# Criando um Scatter Plot.
plt.scatter(iris.data[:, 0], iris.data[:, 1], c=iris.target)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.show()

# %%
# Usando apenas as duas colunas para simplificar a análise.
X = iris.data[:, :2]
y = iris.target

# Dividindo os dados simplificados entre treino e teste.
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Criando um modelo de Regrassão Logistica.
model = LogisticRegression()
model.fit(X_train, Y_train)

# Apresentando a acurácia da previsão.
print("Model score:", model.score(X_test, Y_test))
# Out:
# Model score: 0.8222222222222222

# %%
# Aplicando Padronização de Escala.
scaler = StandardScaler()
scaled_data = scaler.fit_transform(iris.data)

# Apresentando as 5 primeiras linhas dos dois datasets.
print('Original Data')
print(iris.data[:5])
print()
print('Scaled Data')
print(scaled_data[:5])
# Out:
# Original Data
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
#
# Scaled Data
# [[-0.90068117  1.01900435 -1.34022653 -1.3154443 ]
#  [-1.14301691 -0.13197948 -1.34022653 -1.3154443 ]
#  [-1.38535265  0.32841405 -1.39706395 -1.3154443 ]
#  [-1.50652052  0.09821729 -1.2833891  -1.3154443 ]
#  [-1.02184904  1.24920112 -1.34022653 -1.3154443 ]]

# %%
# Dividindo os dados completos entre treino e teste.
X_train, X_test, Y_train, Y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=42)

# Criando um Classificador SVM com um Kernel Linear.
model = SVC(kernel='linear')
model.fit(X_train, Y_train)

# Apresentando a acurácia da previsão.
print("Model score:", model.score(X_test, Y_test))
# Out:
# Model score: 1.0

# %% [markdown]
# ### Diabetes Dataset

# %%
# Carregando o Diabetes Dataset.
diabetes = datasets.load_diabetes()

# %%
# Apresentando o formato dos dados e da variável alvo.
print("Data shape:", diabetes.data.shape)
print("Target shape:", diabetes.target.shape)
# Out:
# Data shape: (442, 10)
# Target shape: (442,)

# %%
# Dividindo os dados entre treino e teste.
X_train, X_test, Y_train, Y_test = train_test_split(diabetes.data, diabetes.target, test_size=0.3, random_state=42)

# %%
# Criando um modelo de Regressão Linear.
model = LinearRegression()
model.fit(X_train, Y_train)

# Apresentando a avaliação do modelo.
print("Model score:", model.score(X_test, Y_test))
# Out:
# Model score: 0.4772897164322617

# %% [markdown]
# ### Wine Dataset

# %%
# Carregando o Wine Dataset.
wine = datasets.load_wine()

# %%
# Dividindo os dados entre treino e teste.
X_train, X_test, Y_train, Y_test = train_test_split(wine.data, wine.target, test_size=0.3, random_state=42)

# %%
# Apresentando o formato dos dados.
print("Training data shape:", X_train.shape)
print("Test data shape:", X_test.shape)
# Out:
# Training data shape: (124, 13)
# Test data shape: (54, 13)

# %%
# Criando um modelo Decision Tree Classifier.
model = DecisionTreeClassifier()
model.fit(X_train, Y_train)

# Apresentando a acurácia da previsão.
print("Model score:", model.score(X_test, Y_test))
# Out:
# Model score: 0.9629629629629629

# %%
# Criando um modelo KNN Classifier com 3 grupos.
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, Y_train)

# Apresentando a acurácia da previsão.
print("Model score:", model.score(X_test, Y_test))
# Out:
# Model score: 0.7407407407407407
